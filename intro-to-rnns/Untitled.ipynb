# %%
def generatorfunction():
    yield(1)
    yield(2)
    yield(3)

# %%
generatorfunction
# Out:
# <function __main__.generatorfunction>

# %%
ourgenerator=generatorfunction()

# %%
next(ourgenerator)
# Out:
# 1

# %%
next(ourgenerator)
# Out:
# 2

# %%
with open("anna.txt",'r')as f:
    lines=f.readlines()
    
print(len(lines))
with open("test.txt",'w')as write:
    write.writelines(lines)
# Out:
# 40263

# %%
lines
# Out:
# ['Chapter 1\r\n',
#  '\r\n',
#  '\r\n',
#  'Happy families are all alike; every unhappy family is unhappy in its own\r\n',
#  'way.\r\n',
#  '\r\n',
#  "Everything was in confusion in the Oblonskys' house. The wife had\r\n",
#  'discovered that the husband was carrying on an intrigue with a French\r\n',
#  'girl, who had been a governess in their family, and she had announced to\r\n',
#  'her husband that she could not go on living in the same house with him.\r\n',
#  'This position of affairs had now lasted three days, and not only the\r\n',
#  'husband and wife themselves, but all the members of their family and\r\n',
#  'household, were painfully conscious of it. Every person in the house\r\n',
#  'felt that there was no sense in their living together, and that the\r\n',
#  'stray people brought together by chance in any inn had more in common\r\n',
#  'with one another than they, the members of the family and household of\r\n',
# ...

# %%
def enterprimenumber():
    prime=10
    return prime

# %%
test=enterprimenumber()

# %%
test
# Out:
# 10

# %%
def testinggenerator():
    yield(10)
    yield(20)
    yield(30)

# %%
newvalue=testinggenerator()

# %%
next(newvalue)
# Out:
# 10

# %%
next(newvalue)
# Out:
# 20

# %%
next(newvalue)
# Out:
# 30
